# %%
import scrublet as scr
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import os
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rc('font', size=14)
plt.rcParams['pdf.fonttype'] = 42

# %%
samples=["/home/luisas/Desktop/m.mtx"]
input = pd.read_table(samples[0])

# %%
#pd.wide_to_long(input, stubnames='ht', i=list(input.columns), j='gene')
# Out:
# ['EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_AGCAGTAGGTAG EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_GGGTGCAGAACA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CCGACCTCGGAA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_TCAACGCCAGAC EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CCCCAGGCGGGT EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_AGACCCGTTTGG EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_AAATCAGCCAAT EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CCCGTTGACACT EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_TCAATGCAGGCC EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CTGACAACGCCA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_TGGCATCTTTGG EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_TTCATCTGCGAA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CTACCGACTAAG EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CACGAGTATCCC EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CAAAATATCGAA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_TGTCGCAAGAAG EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_GTCCGTTTTACA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CGGCGAGCTGTA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CCCCTCCCGAAA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_AGGCGAGACGTC EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_TACCACGAGAAA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_GGAACTTATAGT EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_TAGACCTCGAAC EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_TCACGGATACTA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CTGGGACATCCG EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CGGAGGAATCTA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CATCAATGGGTT EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CGGACGAACAGT EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_GATAACCCACCT EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CCCGCATAGAAC EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_TGTCTCATCTCG EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CCCGCAGTAGCT EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CCGTGAAAATCC EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_TTTGCACCCAAG EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_TCTGACTTTCAT EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CCGCGGAGAAAA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_ATCGTCCTTCAC EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CTTTTCCCGGAT EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CTCTTCGATAAA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_TAACACTCCGGG EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_TGATAGGGTCTT EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_TGGCCAATTACA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_GGTTCCGTCAAT EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_TCCGCGCCATAA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_AATAACCGAGTA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CGAGACCTCCGG EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CTGAAGGGCCTA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_GAACCCGGGCTA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_GTGTTCTTAGTA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_GTGTAGTCGCTC EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_GGAGGCGACTAC EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_GTCCAGCCAAAT EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_TCGTAGTAGAGT EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CGGAATTCACTA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_GCGGTGTTTTTC EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CTATAGCAGTTG EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_ATGACTAATAAT EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_GAGGAGACACAT EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_GCCTCACTGACT EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_AATGGTCACCTC EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CGCCAGACGACC EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_GAGCCGCAGACA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_ATTACCAACTAA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CTGCCATTGGGT EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_TGGAGGACTCCA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_GATTCGCCCCCC EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CCCGTGGAGCCC EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_TACGGCGTTTCT EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CAGACGCGCACG EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_CTTTGCCGCATT EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_ATACCCAGCGAC EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_GACAAACGGTAG EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_TCCCCAGCTAAA EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_GGTCCAACGATC EV0003-irrad-moi1e-1-H004-a1.dge.txt.gz_ACAGCCAAGGCA EV0003-irrad-moi1e-1-H0 ...

# %%
import os
import subprocess


samples=["/home/luisas/Desktop/m.mtx"]


barcodes = {}
features = {}

out_folder = os.path.dirname("/home/luisas/Desktop/")
temp_mtx = os.path.join(out_folder,'temp_umi.mtx')
header = os.path.join(out_folder,'header.mtx')
mtx = os.path.join(out_folder, "out.mtx")
n_lines=0
barcode_index = 1
feature_index = 1

with open(temp_mtx,'w') as mtx_stream:
    for i,sample in enumerate(samples):
        if samples[i] not in sample:
            sys.exit("Sample name not found in file path")
        with open(sample,'r') as input_file:
            next(input_file) # skip first line
            for line in input_file:
                barcode,feature,count = line.strip().split()
                if(not isinstance(samples,str)):
                    barcode = samples[i] + '_' + barcode
                if(barcode not in barcodes):
                    barcodes[barcode] = barcode_index
                    barcode_index += 1
                if(feature not in features):
                    features[feature] = feature_index
                    feature_index += 1
                
                mtx_stream.write('{} {} {}\n'.format(features[feature],barcodes[barcode],count))
                n_lines +=1

with open(header,'w') as header_outfile:
    header_outfile.write("%%MatrixMarket matrix coordinate real general\n")
    header_outfile.write('{} {} {}\n'.format(len(features), len(barcodes), n_lines))
    
subprocess.call("cat {} {} > {}".format(header, temp_mtx, mtx), shell=True)
os.remove(temp_mtx)
os.remove(header)

print(temp_mtx)
# Out:
# /home/luisas/Desktop/temp_umi.mtx

# %%
input_dir = out_folder
counts_matrix = scipy.io.mmread(input_dir + '/out.mtx').T.tocsc()
print('Counts matrix shape: {} rows, {} columns'.format(counts_matrix.shape[0], counts_matrix.shape[1]))
# Out:
# Counts matrix shape: 6198 rows, 13538 columns

# %%
scrub = scr.Scrublet(counts_matrix, expected_doublet_rate=0.06)
doublet_scores, predicted_doublets = scrub.scrub_doublets(min_counts=2, 
                                                          min_cells=3, 
                                                          min_gene_variability_pctl=85, 
                                                          n_prin_comps=30)
scrub.call_doublets(threshold=0.25)
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 6.0%
# 	Estimated  = 20.7%
# Elapsed time: 4.8 seconds
# Detected doublet rate = 3.6%
# Estimated detectable doublet fraction = 12.1%
# Overall doublet rate:
# 	Expected   = 6.0%
# 	Estimated  = 30.1%
# array([False, False, False, ..., False, False, False])

# %%
scrub.plot_histogram();
print('Running UMAP...')
scrub.set_embedding('UMAP', scr.get_umap(scrub.manifold_obs_, 10, min_dist=0.3))
print('Done')
# Out:
# Running UMAP...
# /home/luisas/.local/lib/python3.6/site-packages/numba/typed_passes.py:293: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../../../../../.local/lib/python3.6/site-packages/umap/nndescent.py", line 47:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   state.func_ir.loc))
# Done

# %%
scrub.plot_embedding('UMAP', order_points=True);

# %%
np.savetxt('predicted_doublet_mask.txt', scrub.predicted_doublets_, fmt='%s')
# Out:
# (array([False, False, False, ..., False, False, False]),)
